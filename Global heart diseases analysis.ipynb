# %% [markdown]
# # Global Heart diseases ❤

# %% [markdown]
# # ![Screen Shot 2025-01-13 at 2.54.54 PM.png](data:image/png;base64,...)

# %%
import numpy as np
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import dash
from dash import dcc, html
import plotly.express as px

# %% [markdown]
# # Data Reading

# %%
pd.read_csv('/content/Dataset Heart Disease.csv')
pd.read_csv('/content/cleveland1.csv')
pd.read_csv('/content/cleveland2.csv')



df1 = pd.read_csv('/content/Dataset Heart Disease.csv')
df2 = pd.read_csv('/content/cleveland1.csv')
df3 = pd.read_csv('/content/cleveland2.csv')

df = pd.concat([df1, df2, df3], ignore_index=True)

# %% [markdown]
# ## Data Profiling :

# %%
df.describe()
# Out:
#         Unnamed: 0          age          sex  chest pain type  resting bps  \
# count  1350.000000  2540.000000  2540.000000      2238.000000  1048.000000
# mean    356.271111    53.640551     0.742126         3.038427   132.613550
# std     292.699674     9.340920     0.437550         1.045820    17.367605
# min       0.000000    28.000000     0.000000         1.000000    92.000000
# 25%     117.250000    47.000000     0.000000         2.000000   120.000000
# 50%     247.500000    54.000000     1.000000         3.000000   130.000000
# 75%     599.000000    60.000000     1.000000         4.000000   140.000000
# max    1189.000000    77.000000     1.000000         4.000000   200.000000
#
#        cholesterol  fasting blood sugar  resting ecg  max heart rate  \
# count  2238.000000          2238.000000  2238.000000     2238.000000
# mean    226.663986             0.189455     0.655496      141.224754
# std      85.411506             0.391957     0.823055       25.057841
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  age  sex  chest pain type  resting bps  cholesterol  \
# 0         0.0   40    1              2.0        140.0        289.0
# 1         1.0   49    0              3.0        160.0        180.0
# 2         2.0   37    1              2.0        130.0        283.0
# 3         3.0   48    0              4.0        138.0        214.0
# 4         4.0   54    1              3.0        150.0        195.0
#
#    fasting blood sugar  resting ecg  max heart rate  exercise angina  ...  cp  \
# 0                  0.0          0.0           172.0              0.0  ... NaN
# 1                  0.0          0.0           156.0              0.0  ... NaN
# 2                  0.0          1.0            98.0              0.0  ... NaN
# 3                  0.0          0.0           108.0              1.0  ... NaN
# 4                  0.0          0.0           122.0              0.0  ... NaN
#
#    trestbps  chol  fbs  restecg  thalach  exang  slope  ca  thal
# ...

# %%
df
# Out:
#       Unnamed: 0  age  sex  chest pain type  resting bps  cholesterol  \
# 0            0.0   40    1              2.0        140.0        289.0
# 1            1.0   49    0              3.0        160.0        180.0
# 2            2.0   37    1              2.0        130.0        283.0
# 3            3.0   48    0              4.0        138.0        214.0
# 4            4.0   54    1              3.0        150.0        195.0
# ...          ...  ...  ...              ...          ...          ...
# 2535       723.0   68    0              NaN          NaN          NaN
# 2536       733.0   44    0              NaN          NaN          NaN
# 2537       739.0   52    1              NaN          NaN          NaN
# 2538       843.0   59    1              NaN          NaN          NaN
# 2539       878.0   54    1              NaN          NaN          NaN
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  ...  \
# ...

# %% [markdown]
# # Cleaning (Caping)

# %%
df['sex'] = df['sex'].replace({1: 'male', 0: 'female'})

for col in df.columns:
    if pd.api.types.is_numeric_dtype(df[col]):
        median_val = df[col].median()
        df[col] = df[col].fillna(median_val)
df = df[df['cholesterol'] != 0]

if 'Unnamed: 0' in df.columns:
    df = df.drop(columns=['Unnamed: 0'])
    print("Dropped unnamed column successfully.")
else:
    print("No unnamed column found.")
# Out:
# Dropped unnamed column successfully.

# %%
df
# Out:
#       age     sex  chest pain type  resting bps  cholesterol  \
# 0      40    male              2.0        140.0        289.0
# 1      49  female              3.0        160.0        180.0
# 2      37    male              2.0        130.0        283.0
# 3      48  female              4.0        138.0        214.0
# 4      54    male              3.0        150.0        195.0
# ...   ...     ...              ...          ...          ...
# 2535   68  female              3.0        130.0        234.0
# 2536   44  female              3.0        130.0        234.0
# 2537   52    male              3.0        130.0        234.0
# 2538   59    male              3.0        130.0        234.0
# 2539   54    male              3.0        130.0        234.0
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                     0.0          0.0           172.0              0.0
# 1                     0.0          0.0           156.0              0.0
# ...

# %%
sns.set_style("whitegrid")

fig, axes = plt.subplots(2, 2, figsize=(16, 12))

sns.histplot(df['age'], bins=20, kde=True, color='skyblue', ax=axes[0, 0])
axes[0, 0].set_title('Age Distribution')
axes[0, 0].set_xlabel('Age')
axes[0, 0].set_ylabel('Frequency')

sns.histplot(df['cholesterol'], bins=20, kde=True, color='lightgreen', ax=axes[0, 1])
axes[0, 1].set_title('Cholesterol Distribution')
axes[0, 1].set_xlabel('Cholesterol')
axes[0, 1].set_ylabel('Frequency')

sns.pairplot(df, vars=['age', 'cholesterol', 'resting bps', 'max heart rate'], hue='sex', palette='husl')
plt.suptitle('Pair Plot of Selected Features', y=1.02)

sns.scatterplot(x='age', y='cholesterol', hue='sex', data=df, ax=axes[1, 0], palette='coolwarm')
axes[1, 0].set_title('Cholesterol vs. Age by Sex')
axes[1, 0].set_xlabel('Age')
axes[1, 0].set_ylabel('Cholesterol')

fig.delaxes(axes[1, 1])

plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %% [markdown]
# # **EDA**

# %% [markdown]
# # **Key Insights**

# %%
#--------------------------------------------------#
sns.set_style("whitegrid")

plt.figure(figsize=(20, 14))

plt.subplot(2, 2, 1)
sns.histplot(data=df, x='age', hue='sex', multiple='stack', palette='pastel', bins=20)
plt.title('Age Distribution by Sex')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.subplot(2, 2, 2)
sns.countplot(data=df, x='chest pain type', palette='viridis')
plt.title('Chest Pain Type Distribution')
plt.xlabel('Chest Pain Type')
plt.ylabel('Count')

plt.subplot(2, 2, 3)
sns.scatterplot(data=df, x='cholesterol', y='max heart rate', hue='sex', palette='cool', alpha=0.7)
plt.title('Cholesterol vs. Max Heart Rate')
plt.xlabel('Cholesterol')
plt.ylabel('Max Heart Rate')

plt.subplot(2, 2, 4)

sns.countplot(x='sex', hue='target', data=df, palette='pastel')
plt.title('Heart Disease Prevalence by Sex')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.legend(title='Heart Disease', labels=['No', 'Yes'])
plt.show()

plt.tight_layout()

plt.show()
# Out:
# <ipython-input-256-1cdbedfff3a3>:13: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
